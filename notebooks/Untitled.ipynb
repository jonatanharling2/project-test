# %%
import pandas as pd

df = pd.DataFrame({
    'col1': [1, 2, 3],
    'col2': ['dog', 'cat', 'fish']
})
df

# %% [markdown]
# # Dataframes
# The above code...

# %%
import pandas as pd
df = pd.DataFrame({
    'col1' : [1, 2, 3, 5, 9, 8],
    'col2' : [9, 8, 7, 6, 5, 4]
})

df

# %%
import pandas as pd
df = pd.DataFrame({
    'col1' : [1, 2, 3, 5, 9, 8],
    'col2' : [9, 8, 7, 6, 5, 4]
})

df.print()

# %%
import pandas as pd
df = pd.DataFrame({
    'col1' : [1, 2, 3, 5, 9, 8],
    'col2' : [9, 8, 7, 6, 5, 4]
})

df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter('col1', 'col2', color='g', marker='x')
# Out:
# <AxesSubplot:xlabel='col1', ylabel='col2'>
